# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Kunny Masrukhati
# - **Email:** kunnymrs1234@gmail.com
# - **ID Dicoding:** kunny_masrukhati

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kategori produk apa yang memiliki volume penjualan tertinggi dan terendah?
# - Bagaimana persebaran geografis pelanggan berdasarkan 10 wilayah atau negara dengan jumlah pelanggan terbanyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/product_category_name_translation.csv")
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv("D:/MBKM/Bangkit/3 Analisis data/submission_analisis_data/dataset/sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Pada dataset e-commerce terdapat 9 tabel yaitu, customers_df, geolocation_df, order_items_df, order_payments_df, order_reviews_df, orders_df, product_category_df, products_df, sellers_df

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Pada bagian ini saya akan menilai kualitas dari seluruh data yang telah dikumpulkan

# %%
customers_df.info()
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
geolocation_df.info()
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
# Jumlah duplikasi:  261831

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
duplicate_geolocation = geolocation_df[geolocation_df.duplicated(subset=['geolocation_lat', 'geolocation_lng'], keep=False)]
print(duplicate_geolocation)
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 6                               1047       -23.546273       -46.641225
# 7                               1013       -23.546923       -46.634264
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# Dari hasil diatas dapat disimpulkan bahwa duplikasi tidak perlu dihilangkan

# %%
order_items_df.info()
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# Jumlah duplikasi:  0

# %%
order_payments_df.info()
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# Jumlah duplikasi:  0

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.info()
print("Jumlah duplikasi: ", order_reviews_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
# Jumlah duplikasi:  0

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
orders_df.info()
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# Jumlah duplikasi:  0

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
product_category_df.info()
print("Jumlah duplikasi: ", product_category_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# Jumlah duplikasi:  0

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
products_df.info()
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# Jumlah duplikasi:  0

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
sellers_df.info()
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
# Jumlah duplikasi:  0

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
# - pada tabel order_items_df pada kolom shipping_limit_date memiliki *kesalahan data type,* data type object seharusnya diubah menjadi datetime
# - pada tabel order_payments_df pada kolom payment_installments dan payment_value memiliki *invalid value*
# - pada tabel order_reviews_df terdapat *missing value* di kolom review_comment_title dan review_comment_message. Serta terdapat *kesalahan data type* pada kolom review_creation_date dan review_answer_timestamp (data type object seharusnya datetime)
# - pada tabel orders_df terdapat *missing value* di kolom order_approved_at, order_delivered_carrier_date dan order_delivered_customer_date. Serta terdapat *kesalahan data type* pada kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date dan order_estimated_delivery_date (data type object seharusnya datetime)
# - pada tabel products_df terdapat *invalid value* pada kolom product_weight_g, dan *missing value* di semua kolom kecuali product_id

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Pada bagian ini saya akan membersihkan data dari berbagai masalah yang sudah ditemukan sebelumnya

# %%
datetime_columns = "shipping_limit_date"
order_items_df[datetime_columns] = pd.to_datetime(order_items_df[datetime_columns])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# Berdasarkan kode diatas, saya sudah berhasil membersihkan masalah terkait type data yang ada pada tabel order_items_df. Selanjutnya saya akan melakukan cleaning pada order_reviews_df

# %%
datetime_columns = ["review_creation_date", "review_answer_timestamp"]
for column in datetime_columns:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# Berdasarkan kode diatas, saya sudah berhasil mengubah type data pada kolom review_creation_date dan review_answer_timestamp menjadi datetime. Selanjutnya saya akan melakukan cleaning untuk missing value pada kolom review_comment_title dan review_comment_title

# %%
order_reviews_df[order_reviews_df['review_comment_title'].isna() | order_reviews_df['review_comment_message'].isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# Dari hasil diatas dapat dilihat bahwa kolom review_comment_title dan review_comment_message tidak perlu diisi karena tidak akan mempengaruhi hasil analisis sehingga saya bisa tetap membiarkannya *kosong* atau mengisinya dengan string tertentu.

# %%
order_reviews_df['review_comment_title'] = order_reviews_df['review_comment_title'].fillna('No Review')
order_reviews_df['review_comment_message'] = order_reviews_df['review_comment_message'].fillna('No Review')

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# Hasil di atas menunjukkan bahwa saya telah berhasil melakukan cleaning pada tabel order_reviews_df. Selanjutnya saya akan melakukan cleaning pada tabel order_payments_df

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
zero_installments = order_payments_df[order_payments_df['payment_installments'] == 0]
print(f"Jumlah baris dengan cicilan 0: {len(zero_installments)}")
print(zero_installments.head())
# Out:
# Jumlah baris dengan cicilan 0: 2
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 79014  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69
# 79014                     0         129.94

# %%
credit_card_payments = order_payments_df[order_payments_df['payment_type'] == 'credit_card']
print(f"Jumlah pembayaran dengan credit card: {len(credit_card_payments)}")
print(credit_card_payments.head())
# Out:
# Jumlah pembayaran dengan credit card: 76795
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Dari situ dapat dilihat bahwa terdapat kesalahan pada payment_installments, selanjutnya saya akan mengganti nilai 0 menggunakan mode

# %%
mode_installments = order_payments_df['payment_installments'].mode()[0]
print("Mode dari payment_installments:", mode_installments)
# Out:
# Mode dari payment_installments: 1

# %% [markdown]
# Setelah mendapatkan nilai mode, kemudian saya mengganti 0 tadi dengan mode yang didapatkan

# %%
order_payments_df['payment_installments'] = order_payments_df['payment_installments'].replace(0, 1)

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853368     154.100380
# std              0.706584              2.687034     217.494064
# min              1.000000              1.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# Setelah itu saya berpindah ke payment_value

# %%
zero_payment = order_payments_df[order_payments_df['payment_value'] == 0]
print(f"Jumlah baris dengan nilai 0: {len(zero_payment)}")
print(zero_payment.head())
# Out:
# Jumlah baris dengan nilai 0: 6
#                                order_id  payment_sequential payment_type  \
# 19922  8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744  6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 62674  45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
#
#        payment_installments  payment_value
# 19922                     1            0.0
# 36822                     1            0.0
# 43744                     1            0.0
# 62674                     1            0.0
# 77885                     1            0.0

# %%
not_defined_payments = order_payments_df[order_payments_df['payment_type'] == 'not_defined']
print(f"Jumlah pembayaran: {len(not_defined_payments)}")
print(not_defined_payments.head())
# Out:
# Jumlah pembayaran: 3
#                                order_id  payment_sequential payment_type  \
# 51280  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value
# 51280                     1            0.0
# 57411                     1            0.0
# 94427                     1            0.0

# %%
order_details = orders_df[orders_df['order_id'] == '4637ca194b6387e2d538dc89b124b0ee']
print(order_details)
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
voucher_payments = order_payments_df[order_payments_df['payment_type'] == 'voucher']
print(f"Jumlah pembayaran dengan: {len(voucher_payments)}")
print(voucher_payments.head())
# Out:
# Jumlah pembayaran dengan: 5775
#                              order_id  payment_sequential payment_type  \
# 25   5cfd514482e22bc992e7693f0e3e8df7                   2      voucher
# 68   947e9c6bfd83a06953c420ef92d3da6e                   1      voucher
# 70   e3e9e3295f4e1512167c232a0aaae8a5                   1      voucher
# 75   3689194c14ad4e2e7361ebd1df0e77b0                   2      voucher
# 102  21b8b46679ea6482cbf911d960490048                   2      voucher
#
#      payment_installments  payment_value
# 25                      1          45.17
# 68                      1          69.46
# 70                      1          50.80
# 75                      1          57.53
# 102                     1          43.12

# %% [markdown]
# Dari situ dapat dilihat bahwa payment_value bernilai 0 berasal dari type payment not_defined dan voucher. Pada type payment not_defined saya akan melakukan drop dan pada voucher akan tetap dibiarkan bernilai 0.0 karena itu memungkinkan.

# %%
order_payments_df.drop(order_payments_df[order_payments_df['payment_type'] == 'not_defined'].index, inplace=True)

# %%
zero_payment = order_payments_df[order_payments_df['payment_value'] == 0]
print(f"Jumlah baris dengan cicilan 0: {len(zero_payment)}")
print(zero_payment.head())
# Out:
# Jumlah baris dengan cicilan 0: 6
#                                order_id  payment_sequential payment_type  \
# 19922  8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744  6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 62674  45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
#
#        payment_installments  payment_value
# 19922                     1            0.0
# 36822                     1            0.0
# 43744                     1            0.0
# 62674                     1            0.0
# 77885                     1            0.0

# %% [markdown]
# Sekarang tabel order_payments_df sudah bersih. Selanjutnya saya berpindah ke orders_df

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df[orders_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# Pada kode diatas dapat dilihat bahwa NaN ditemuka pada orderan yang tidak selesai. Untuk mengatasi masalah tersebut saya bisa mengisinya dengan pd.NAT untuk mempertahankan data dan untuk mendukung analisis kedepannya. Namun, karena pada kasus ini data tersebut mempengaruhi analisa dan untuk memastikan bahwa analisis yang dilakukan lebih akurat dan relevan, serta hanya melibatkan pelanggan yang aktif dalam transaksi maka saya akan menghapus data yang memiliki nilai NaN tersebut.

# %%
orders_df.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], axis=0, inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Saya sudah berhasil membersihkan data NaN pada tabel orders_df. Selanjutnya saya akan melakukan cleaning terhadap data type

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]
for column in datetime_columns:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %% [markdown]
# Saya telah berhasil melakukan cleaning pada tabel orders_df. Selanjutnya saya akan melakukan cleaning pada tabel products_df untuk melakukan cleaning pada invalid value yaitu product_weight_g bernilai 0.

# %%
zero_weight_df = products_df[products_df['product_weight_g'] == 0]
print(f"Jumlah baris dengan value 0: {len(zero_weight_df)}")
print(zero_weight_df)
# Out:
# Jumlah baris dengan value 0: 4
#                              product_id product_category_name  \
# 9769   81781c0fed9fe1ad6e8c81fca1e1cb08       cama_mesa_banho
# 13683  8038040ee2a71048d4bdbbdc985b69ab       cama_mesa_banho
# 14997  36ba42dd187055e1fbe943b2d11430ca       cama_mesa_banho
# 32079  e673e90efa65a5409ff4196c038bb5af       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 9769                  51.0                       529.0                 1.0
# 13683                 48.0                       528.0                 1.0
# 14997                 53.0                       528.0                 1.0
# 32079                 53.0                       528.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 9769                0.0               30.0               25.0
# 13683               0.0               30.0               25.0
# ...

# %% [markdown]
# Selanjutnya kita akan mengganti nilai 0 tersebut dengan menggunakan median

# %%
median_weight = products_df['product_weight_g'].median()
print("Median dari product_weight_g:", median_weight)
# Out:
# Median dari product_weight_g: 700.0

# %%
products_df['product_weight_g'] = products_df['product_weight_g'].replace(0, median_weight)

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.557468          30.815078          16.937661
# std         4282.000497          16.914458          13.637554
# ...

# %% [markdown]
# Setelah berhasil melakukan cleaning pada invalid value, selanjutnya saya melakukan cleaning pada missing value

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df[products_df.product_name_lenght.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df[products_df.product_description_lenght.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df[products_df.product_photos_qty.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# Dari hasil tersebut dapat dilihat bahwa pada kolom product_category_name, product_name_lenght, product_description_lenght, product_photos_qty memiliki NaN yang sama. Dan karena nilai NaN berada pada kolom yang mengandung informasi penting dan itu tidak bisa digantikan, maka saya akan melakukan drop pada baris-baris tersebut

# %%
products_df.dropna(subset=['product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty'], inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              1
# product_length_cm             1
# product_height_cm             1
# product_width_cm              1
# dtype: int64

# %% [markdown]
# Selanjutnya pada kolom product_weight_g, product_length_cm, product_height_cm, product_width_cm

# %%
products_df[products_df.product_weight_g.isna()]
# Out:
#                             product_id product_category_name  \
# 8578  09ff539a621711667c43eba6a3bd8466                 bebes
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                 60.0                       865.0                 3.0
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 8578               NaN                NaN                NaN               NaN

# %% [markdown]
# Dari situ dapat dilihat bahwa keempat kolom yang memiliki nilai NaN ada pada baris yang sama dan itu membutuhkan nilai yang valid sehingga saya akan melakukan drop pada baris tersebut

# %%
products_df.dropna(subset=['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Sekarang semua tabel pada dataset e-comerce sudah bersih

# %% [markdown]
# **Insight:**
# - Dari proses cleaning yang telah saya lakukan, saya berhasil menyelesaikan berbagai macam permasalahan yang saya temukan pada fase sebelumnya pada tabel order_items_df, order_payments_df, order_reviews_df, orders_df, dan products_df
# - Berbagaimacam permasalahan yang berhasil dibersihkan adalah terkait missing value, invalid value, dan kesalahan type data
# - Solusi yang diambil dalam menyelesaikan permasalahan diantaranya, melakukan drop, mengisi atau mengubah value menggunakan nilai yang sesuai (misalnya menggunakan median), dan mengubah type data yang tidak sesuai

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore customers_df

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Berdasarkan rangkuman diatas, saya memperoleh informasi bahwa pelanggan paling banyak tinggal di kota **sao paulo** dan di negara **SP**. Selanjutnya saya akan mencoba melihat detail demografi pelanggan berdasarkan kota dan negaranya

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# agisse                1
# vieiras               1
# bertopolis            1
# abadiania             1
# xexeu                 1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil tersebut dapat dilihat bahwa pelanggan kita tersebar di banyak tempat dengan jumlah yang beragam.

# %% [markdown]
# ### Explore orders_df, order_payments_df dan order_items_df

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         96461                          96461
# ...

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103883       103883.000000       103883
# unique                             99437                 NaN            4
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092681          NaN
# std                                  NaN            0.706594          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# Untuk memudahkan dalam melakukan eksplorasi, maka saya akan menggabungkan semua tabel order tersebut

# %%
orders_payments_df = pd.merge(
    left=orders_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_items_payments_df = pd.merge(
    left=orders_payments_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_items_payments_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Dari gabungan tabel diatas saya akan mencoba eksplor

# %%
orders_items_payments_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                             115021                            115021
# unique                             96461                             96461
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %% [markdown]
# Berdasarkan data diatas kita mendapatkan informasi mengenai pendapatan terbesar dan terkecil yang diperoleh dari order pelanggan

# %%
product_category_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)

# %% [markdown]
# ### Explore products_df, product_category_df, dan orders_items_payments_df

# %%
orders_items_products_df = pd.merge(
    left=orders_items_payments_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
orders_products_df = pd.merge(
    left=orders_items_products_df,
    right=product_category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
orders_products_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_products_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                             115021                            115021
# unique                             96461                             96461
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
orders_products_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
    "order_item_id": "count",
    "price": ["sum", "min", "max"], 
})
# Out:
#                           product_id order_item_id      price
#                              nunique         count        sum    min      max
# product_category_name
# agro_industria_e_comercio         71           246   81877.58  12.99  2990.00
# alimentos                         79           515   29457.18   9.99   274.99
# alimentos_bebidas                 99           279   16118.93   6.50   699.90
# artes                             52           207   24176.63   5.35  6499.00
# artes_e_artesanato                19            24    1814.01   9.80   289.49
# ...                              ...           ...        ...    ...      ...
# sinalizacao_e_seguranca           91           199   21390.63   4.50   740.00
# tablets_impressao_imagem           9            87    7840.31  14.90   889.99
# telefonia                       1112          4601  325423.00   5.00  2428.00
# telefonia_fixa                   113           261   56033.48   6.00  1790.00
# ...

# %% [markdown]
# Dari tabel diatas kita mendapatkan informasi terkait jumlah produk per kategori, volume penjualan, serta data total, harga minimum, dan maksimum produk per kategori.

# %% [markdown]
# ### Explore customers_df dan orders_products_df

# %%
main_data_df = pd.merge(
    left=orders_products_df,  
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
main_data_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
main_data_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15044
# 1         rio de janeiro      6603
# 2         belo horizonte      2697
# 3               brasilia      2071
# 4               curitiba      1489
# 5               campinas      1406
# 6           porto alegre      1341
# 7               salvador      1188
# 8              guarulhos      1143
# 9  sao bernardo do campo       911

# %% [markdown]
# Data diatas memberikan informasi terkait jumlah order berdasarkan kota

# %%
main_data_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   customer_state  order_id
# 0             SP     40489
# 1             RJ     12351
# 2             MG     11352
# 3             RS      5342
# 4             PR      4923
# 5             SC      3547
# 6             BA      3256
# 7             DF      2080
# 8             ES      1995
# 9             GO      1957

# %% [markdown]
# Data diatas memberikan informasi terkait jumlah order berdasarkan negara

# %%
main_data_df.groupby(by=["customer_state", "product_category_name"]).agg({
    "order_item_id": "sum",
    "payment_value": "sum"
})
# Out:
#                                             order_item_id  payment_value
# customer_state product_category_name
# AC             artigos_de_natal                         1         130.85
#                automotivo                               5         661.91
#                bebes                                    3         871.97
#                beleza_saude                             8        2067.62
#                brinquedos                               3         318.05
# ...                                                   ...            ...
# TO             portateis_casa_forno_e_cafe              1        2094.44
#                relogios_presentes                      33        6719.31
#                telefonia                               22        2015.52
#                telefonia_fixa                           2        1444.57
#                utilidades_domesticas                   18        1645.97
#
# [1362 rows x 2 columns]

# %% [markdown]
# Data diatas memberikan informasi terkait jumlah penjualan dan pendapatan berdasarkan negara dan nama kategori produk yang ada.

# %% [markdown]
# **Insight:**
# - Pada tahap ini, saya melakukan eksplorasi pada sejumlah dataset yang terkait yaitu, customers_df, orders_df, order_payments_df, order_items_df, products_df, dan product_category_df
# - Saya melakukan march/join pada tabel-tabel yang membutuhkan untuk memperluas proses eksplore dan menggabungkan semua tabel yang diperlukan dengan nama main_data_df
# - Dari proses eksplore tadi saya mendapatkan beberapa poin penting yaitu, pelanggan paling banyak tinggal di kota *sao paulo* dan di negara *SP*, pendapatan terbesar dan terkecil yang diperoleh dari order pelanggan,  jumlah produk per kategori, volume penjualan, serta data total, harga minimum, dan maksimum produk per kategori, jumlah order berdasarkan kota/negara, serta analisis jumlah penjualan dan pendapatan berdasarkan negara dan nama kategori produk yang ada.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Kategori produk apa yang memiliki volume penjualan tertinggi dan terendah?

# %%
sum_order_items_df = main_data_df.groupby("product_category_name").order_item_id.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#      product_category_name  order_item_id
# 0          cama_mesa_banho          14347
# 1         moveis_decoracao          11800
# 2             beleza_saude          11195
# 3            esporte_lazer          10041
# 4   informatica_acessorios           9960
# 5    utilidades_domesticas           9296
# 6       relogios_presentes           6670
# 7       ferramentas_jardim           5995
# 8                telefonia           5216
# 9               automotivo           4932
# 10              brinquedos           4518
# 11              cool_stuff           4194
# 12              perfumaria           3850
# 13                   bebes           3470
# 14             eletronicos           3131

# %% [markdown]
# Data tersebut adalah data frame baru yang digunakan untuk menampung informasi terkait jumlah penjualan tiap produk. Selanjutnya saya akan memvisualisasikannya dalam bentuk bar chart.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#ff7f0e", "#c7c7c7", "#c7c7c7", "#c7c7c7", "#c7c7c7"]

sns.barplot(x="order_item_id", y="product_category_name", hue="product_category_name", 
            data=sum_order_items_df.head(5), palette=colors, ax=ax[0], legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Selling Items", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_item_id", y="product_category_name", hue="product_category_name", 
            data=sum_order_items_df.sort_values(by="order_item_id", ascending=True).head(5), 
            palette=colors, ax=ax[1], legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Least Selling Items", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Least Selling Items", fontsize=20)
plt.show()

# %% [markdown]
# Berdasarkan diagram diatas, dapat dilihat bahwa kategori produk dengan penjualan tertinggi adalah cama_mesa_banho, dan dengan penjualan terendah adalah seguros_e_servicos

# %% [markdown]
# ### Pertanyaan 2: Bagaimana persebaran geografis pelanggan berdasarkan 10 wilayah atau negara dengan jumlah pelanggan terbanyak?

# %%
bystate_df = main_data_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={"customer_id": "customer_count"}, inplace=True)
bystate_df.head(15)
# Out:
#    customer_state  customer_count
# 0              AC              80
# 1              AL             397
# 2              AM             145
# 3              AP              67
# 4              BA            3256
# 5              CE            1278
# 6              DF            2080
# 7              ES            1995
# 8              GO            1957
# 9              MA             716
# 10             MG           11352
# 11             MS             701
# 12             MT             886
# 13             PA             946
# 14             PB             517

# %% [markdown]
# Data tersebut adalah data frame baru yang digunakan untuk menampung informasi terkait jumlah pelanggan yang ada di setiap negara. Namun, belum diurutkan. Selanjutnya saya akan memvisualisasikannya dalam bentuk bar chart dan mengambil 10 teratas.

# %%
top_10_countries = bystate_df.sort_values(by="customer_count", ascending=False).head(10)

plt.figure(figsize=(10, 5))
colors_ = ["#ff7f0e"] * 10 

sns.barplot(
    x="customer_state",
    y="customer_count",
    data=top_10_countries,
    palette=colors_,
    hue="customer_state",
    dodge=False,
    legend=False
)

plt.title("Top 10 States with Most Customers", loc="center", fontsize=15)
plt.xlabel(None)
plt.ylabel(None)
plt.tick_params(axis='x', labelsize=12, rotation=45)

plt.show()

# %% [markdown]
# Berdasarkan diagram diatas, dapat dilihat 10 negara yang memiliki pelanggan terbanyak, dan yang menduduki peringkat pertama adalah SP. Selanjutnya saya akan melakukan analisis lanjutan untuk melihat detail perilaku pembelian berdasarkan negara

# %% [markdown]
# **Insight:**
# - Pada tahap ini, saya berhasil membuat visualisasi data yang menjawab kedua pertanyaan sebelumnya. Visualisasi data tersebut saya tuangkan dalam bentuk bar chart karena bentuk tersebut adalah bentuk yang paling sesuai untuk permasalahan yang ada
# - Terdapat 2 visualisasi data yang saya buat yaitu, terkait kategori produk yang paling banyak dan paling sedikit dijual dan 10 negara asal pelanggan terbanyak

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# #### RFM Analysis

# %%
rfm_df = main_data_df.groupby(by="customer_state", as_index=False).agg({
    "order_delivered_customer_date": "max",
    "order_id": "nunique",
    "payment_value": "sum"
})
rfm_df.columns = ["customer_state", "max_order_timestamp", "frequency", "monetary"]
 
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_delivered_customer_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#   customer_state  frequency   monetary  recency
# 0             AC         80   24890.49       49
# 1             AL        397  108425.07       28
# 2             AM        145   34503.04       49
# 3             AP         67   21521.71       48
# 4             BA       3256  773182.02       27

# %% [markdown]
# Data frame diatas adalah informasi terkait recency, frequency, dan monetary. Selanjutnya saya akan mendefinisikan 5 pelanggan terbaik (berdasarkan negara) berdasarkan parameter frequency, monetary, dan recancy.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#ff7f0e"] * 5 

sns.barplot(y="recency", x="customer_state", data=rfm_df.sort_values(by="recency", ascending=True).head(5), hue="customer_state", palette=colors, legend=False, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=15, rotation=45)

sns.barplot(y="frequency", x="customer_state", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), hue="customer_state", palette=colors, legend=False, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15, rotation=45)

sns.barplot(y="monetary", x="customer_state", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), hue="customer_state", palette=colors, legend=False, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15, rotation=45)

plt.suptitle("Best Customer Based on RFM Parameters (customer_state)", fontsize=20)
plt.show()

# %% [markdown]
# **Insight:**
# - Menggunakan parameter RFM untuk mendukung pertanyaan nomor 2 untuk menjelaskan detail perilaku pembelian berdasarkan negara

# %%
main_data_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **- Conclution pertanyaan 1: Kategori produk apa yang memiliki volume penjualan tertinggi dan terendah?**
# Berdasarkan hasil analisis ini dapat disimpulkan bahwa produk dengan volume penjualan tertinggi adalah *cama_mesa_banho* dan produk dengan volume penjualan terendah adalah *seguros_e_servicos*
#
# **- Conclution pertanyaan 2: Bagaimana persebaran geografis pelanggan berdasarkan 10 negara dengan jumlah pelanggan terbanyak?**
# Berdasarkan hasil analisis ini dapat disimpulkan bahwa persebaran geografis pelanggan berdasarkan 10 negara terbanyak tersebar pada negara *SP, RJ, MG, RS, PR, SC, BA, DF, ES, GO* dengan negara dengan pelanggan terbanyak adalah *SP*
#
# **- Conclution tambahan (RFM Analysis):**
# Berdasarkan hasil analisis tambahan yang mendukung pertanyaan nomor 2 ini dapat disimpulkan bahwa kostumer terbaik (berdasarkan negara) berdasarkan recency (hari) adalah *ES, MG, PE, DF, RS*, berdasarkan frequency adalah *SP, RJ, MG, RS, PR*, dan berdasarkan monetary adalah *SP, RJ, MG, RS, PR*
